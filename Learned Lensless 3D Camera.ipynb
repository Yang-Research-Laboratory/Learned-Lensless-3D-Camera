# %%
# !nvidia-smi
# Out:
# Mon Oct 10 17:11:13 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 496.13       Driver Version: 496.13       CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10G         TCC  | 00000000:00:1E.0 Off |                    0 |
# |  0%   22C    P8     9W / 300W |      0MiB / 22841MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
import keras
# from keras import layers
from keras import backend as K
import keras.layers as layers
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import regularizers

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.8
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
keras.__version__
# Out:
# '2.7.0'

# %% [markdown]
# # Load captured images for 3D imaging demonstration

# %%
from scipy.io import loadmat
datav1 = loadmat("datasets//vdata_lineoftoys.mat")
# import h5py
# datav1 = h5py.File('datav7.mat')
# import mat73
# datav1 = mat73.loadmat('datav7_2.mat')
Xvr = datav1['Xvr']
Xvr = Xvr.astype('float32')
# Xvr = np.expand_dims(Xvr,0)
Xvr = np.expand_dims(Xvr,3)
Xvg = datav1['Xvg']
Xvg = Xvg.astype('float32')
# Xvg = np.expand_dims(Xvg,0)
Xvg = np.expand_dims(Xvg,3)
Xvb = datav1['Xvb']
Xvb = Xvb.astype('float32')
# Xvb = np.expand_dims(Xvb,0)
Xvb = np.expand_dims(Xvb,3)
pid=0
rawr=Xvr[pid]
rawr=np.expand_dims(rawr,0)
rawg=Xvg[pid]
rawg=np.expand_dims(rawg,0)
rawb=Xvb[pid]
rawb=np.expand_dims(rawb,0)

# %%
Xvr.shape
# Out:
# (5, 1376, 2064, 1)

# %%
plt.imshow(np.concatenate((Xvr[0],Xvg[0],Xvb[0]),axis=2))
plt.title('measured image')
# Out:
# Text(0.5, 1.0, 'measured image')

# %% [markdown]
# # Load saved models

# %%
from models import *
from utils import *

# %%
reconM1 = keras.models.load_model('reconM_1.h5', custom_objects = {'Hadamard': Hadamard})
reconM2 = keras.models.load_model('reconM_2.h5', custom_objects = {'Hadamard': Hadamard})
reconM3 = keras.models.load_model('reconM_3.h5', custom_objects = {'Hadamard': Hadamard})
reconM4 = keras.models.load_model('reconM_4.h5', custom_objects = {'Hadamard': Hadamard})
reconM5 = keras.models.load_model('reconM_5.h5', custom_objects = {'Hadamard': Hadamard})
reconM6 = keras.models.load_model('reconM_6.h5', custom_objects = {'Hadamard': Hadamard})
reconM7 = keras.models.load_model('reconM_7.h5', custom_objects = {'Hadamard': Hadamard})
reconM8 = keras.models.load_model('reconM_8.h5', custom_objects = {'Hadamard': Hadamard})
reconM9 = keras.models.load_model('reconM_9.h5', custom_objects = {'Hadamard': Hadamard})
reconM10 = keras.models.load_model('reconM_10.h5', custom_objects = {'Hadamard': Hadamard})
reconM11 = keras.models.load_model('reconM_11.h5', custom_objects = {'Hadamard': Hadamard})
reconM12 = keras.models.load_model('reconM_12.h5', custom_objects = {'Hadamard': Hadamard})
reconM13 = keras.models.load_model('reconM_13.h5', custom_objects = {'Hadamard': Hadamard})
reconM14 = keras.models.load_model('reconM_14.h5', custom_objects = {'Hadamard': Hadamard})

# %%
fullgenerator = keras.models.load_model('fullgenerator.h5', custom_objects = {'Hadamard': Hadamard,'custom_objective': custom_objective})

# %%
ds1 = 300
ds2 = 300
tsize = 256
enhanceM = enhanceModule(ds1,ds2,tsize)
enhanceM.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 300, 300, 1  0           []
#                                 )]
#
#  input_5 (InputLayer)           [(None, 300, 300, 1  0           []
#                                 )]
#
#  input_6 (InputLayer)           [(None, 300, 300, 1  0           []
#                                 )]
#
#  resizing (Resizing)            (None, 256, 256, 1)  0           ['input_4[0][0]']
#
#  resizing_1 (Resizing)          (None, 256, 256, 1)  0           ['input_5[0][0]']
#
#  resizing_2 (Resizing)          (None, 256, 256, 1)  0           ['input_6[0][0]']
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['resizing[0][0]',
#                                 )                                 'resizing_1[0][0]',
#                                                                   'resizing_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['conv2d[0][0]',
#                                 )                                 'conv2d[1][0]',
#                                                                   'conv2d[2][0]']
#
#  mp_2_1r (MaxPooling2D)         (None, 128, 128, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  mp_2_1g (MaxPooling2D)         (None, 128, 128, 32  0           ['conv2d_1[1][0]']
#                                 )
#
#  mp_2_1b (MaxPooling2D)         (None, 128, 128, 32  0           ['conv2d_1[2][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['mp_2_1r[0][0]',
#                                 )                                 'mp_2_1g[0][0]',
#                                                                   'mp_2_1b[0][0]']
#
#  mp_3_1r (MaxPooling2D)         (None, 64, 64, 64)   0           ['conv2d_2[0][0]']
#
#  mp_3_1g (MaxPooling2D)         (None, 64, 64, 64)   0           ['conv2d_2[1][0]']
#
#  mp_3_1b (MaxPooling2D)         (None, 64, 64, 64)   0           ['conv2d_2[2][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['mp_3_1r[0][0]',
#                                                                   'mp_3_1g[0][0]',
#                                                                   'mp_3_1b[0][0]']
#
#  mp_4_1r (MaxPooling2D)         (None, 32, 32, 64)   0           ['conv2d_3[0][0]']
#
#  mp_4_1g (MaxPooling2D)         (None, 32, 32, 64)   0           ['conv2d_3[1][0]']
#
#  mp_4_1b (MaxPooling2D)         (None, 32, 32, 64)   0           ['conv2d_3[2][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['mp_4_1r[0][0]',
#                                                                   'mp_4_1g[0][0]',
#                                                                   'mp_4_1b[0][0]']
#
#  mp_5_1r (MaxPooling2D)         (None, 16, 16, 128)  0           ['conv2d_4[0][0]']
#
#  mp_5_1g (MaxPooling2D)         (None, 16, 16, 128)  0           ['conv2d_4[1][0]']
#
#  mp_5_1b (MaxPooling2D)         (None, 16, 16, 128)  0           ['conv2d_4[2][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  295168      ['mp_5_1r[0][0]',
#                                                                   'mp_5_1g[0][0]',
#                                                                   'mp_5_1b[0][0]']
#
#  mp_6_1r (MaxPooling2D)         (None, 8, 8, 256)    0           ['conv2d_5[0][0]']
#
#  mp_6_1g (MaxPooling2D)         (None, 8, 8, 256)    0           ['conv2d_5[1][0]']
#
#  mp_6_1b (MaxPooling2D)         (None, 8, 8, 256)    0           ['conv2d_5[2][0]']
#
#  dropout (Dropout)              (None, 8, 8, 256)    0           ['mp_6_1r[0][0]']
#
#  dropout_2 (Dropout)            (None, 8, 8, 256)    0           ['mp_6_1g[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 256)    0           ['mp_6_1b[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 512)    1180160     ['dropout[0][0]',
#                                                                   'dropout_2[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 8, 8, 512)    0           ['conv2d_6[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 512)    0           ['conv2d_6[1][0]']
#
#  dropout_5 (Dropout)            (None, 8, 8, 512)    0           ['conv2d_6[2][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    1179904     ['dropout_1[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 128)    295040      ['conv2d_7[0][0]',
#                                                                   'conv2d_7[1][0]',
#                                                                   'conv2d_7[2][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 128)  0           ['conv2d_8[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 16, 16, 128)  0          ['conv2d_8[1][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 16, 16, 128)  0          ['conv2d_8[2][0]']
#  )
#
#  concatenate (Concatenate)      (None, 16, 16, 384)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 16, 16, 384)  0           ['up_sampling2d_5[0][0]',
#                                                                   'conv2d_5[1][0]']
#
#  concatenate_10 (Concatenate)   (None, 16, 16, 384)  0           ['up_sampling2d_10[0][0]',
#                                                                   'conv2d_5[2][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  442496      ['concatenate[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'concatenate_10[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_9[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_9[1][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 32, 32, 128)  0          ['conv2d_9[2][0]']
#  )
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['up_sampling2d_1[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 256)  0           ['up_sampling2d_6[0][0]',
#                                                                   'conv2d_4[1][0]']
#
#  concatenate_11 (Concatenate)   (None, 32, 32, 256)  0           ['up_sampling2d_11[0][0]',
#                                                                   'conv2d_4[2][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   147520      ['concatenate_1[0][0]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'concatenate_11[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_10[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_10[1][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 64, 64, 64)  0           ['conv2d_10[2][0]']
#  )
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['up_sampling2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 128)  0           ['up_sampling2d_7[0][0]',
#                                                                   'conv2d_3[1][0]']
#
#  concatenate_12 (Concatenate)   (None, 64, 64, 128)  0           ['up_sampling2d_12[0][0]',
#                                                                   'conv2d_3[2][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 32)   36896       ['concatenate_2[0][0]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'concatenate_12[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 32  0          ['conv2d_11[0][0]']
#                                 )
#
#  up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 32  0          ['conv2d_11[1][0]']
#                                 )
#
#  up_sampling2d_13 (UpSampling2D  (None, 128, 128, 32  0          ['conv2d_11[2][0]']
#  )                              )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'conv2d_2[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_8[0][0]',
#                                 )                                 'conv2d_2[1][0]']
#
#  concatenate_13 (Concatenate)   (None, 128, 128, 96  0           ['up_sampling2d_13[0][0]',
#                                 )                                 'conv2d_2[2][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 32  27680       ['concatenate_3[0][0]',
#                                 )                                 'concatenate_8[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 32  0          ['conv2d_12[0][0]']
#                                 )
#
#  up_sampling2d_9 (UpSampling2D)  (None, 256, 256, 32  0          ['conv2d_12[1][0]']
#                                 )
#
#  up_sampling2d_14 (UpSampling2D  (None, 256, 256, 32  0          ['conv2d_12[2][0]']
#  )                              )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 64  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 256, 256, 64  0           ['up_sampling2d_9[0][0]',
#                                 )                                 'conv2d_1[1][0]']
#
#  concatenate_14 (Concatenate)   (None, 256, 256, 64  0           ['up_sampling2d_14[0][0]',
#                                 )                                 'conv2d_1[2][0]']
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['concatenate_4[0][0]']
#  alization)                     )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['concatenate_9[0][0]']
#  rmalization)                   )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 64  256        ['concatenate_14[0][0]']
#  rmalization)                   )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 1)  577         ['batch_normalization[0][0]',
#                                                                   'batch_normalization_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 256, 256, 3)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_13[1][0]',
#                                                                   'conv2d_13[2][0]']
#
# ==================================================================================================
# Total params: 3,745,057
# Trainable params: 3,744,673
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
# assign weights from pre-trained enhancement module
for lid in range(12,len(fullgenerator.layers)):
    weights = fullgenerator.layers[lid].get_weights()
    enhanceM.layers[lid-6].set_weights(weights)

# %% [markdown]
# # Reconstruction and enhancement at trained distances

# %%
reconMlist = [reconM1,reconM2,reconM3,reconM4,reconM5,reconM6,reconM7,reconM8,reconM9,reconM10,reconM11,reconM12,reconM13,reconM14]
recon_stack = np.zeros((15,ds1,ds2,3))
generated_stack = np.zeros((15,tsize,tsize,3))
# generated_stack3 = np.zeros((15,256,256,3))
ofs = loadmat("datasets//ofs.mat")
ofx = ofs['ofx']
ofy = ofs['ofy']
# ofx = np.ndarray.tolist(ofx)
# ofy = np.ndarray.tolist(ofy)
tcenter1 = 730
tcenter2 = 930
lid=6
for rid in range(0,14):
    temp = reconout(reconMlist[rid],ofx[rid],ofy[rid],tcenter1,tcenter2,lid,rawr,rawg,rawb)
    recon_stack[rid] = temp
    inr = temp[:,:,0]
    inr = np.expand_dims(inr,0)
    inr = np.expand_dims(inr,3)
    ing = temp[:,:,1]
    ing = np.expand_dims(ing,0)
    ing = np.expand_dims(ing,3)
    inb = temp[:,:,2]
    inb = np.expand_dims(inb,0)
    inb = np.expand_dims(inb,3)
    generated_stack[rid] = generatorout(enhanceM,inr,ing,inb)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C8BCE0B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C8D0D41F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
disd=[19,22,25,28,32,36,40,45,50,55,60]
for rid in range(0,11):
#     f, ax = plt.subplots(1, 2, figsize=(15,15))
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(recon_stack[rid+3])
    plt.title(str(disd[rid])+'cm reconM output')
    plt.subplot(1,2,2)
    plt.imshow(generated_stack[rid+3])
    plt.title(str(disd[rid])+'cm enhanceM output')

# %% [markdown]
# # Load captured images for see-through target demonstration

# %%
from scipy.io import loadmat
datav1=loadmat("datasets//vdata_seethrough.mat")
# import h5py
# datav1 = h5py.File('datav7.mat')
# import mat73
# datav1 = mat73.loadmat('datav7_2.mat')
Xvr=datav1['Xvr']
Xvr=Xvr.astype('float32')
# Xvr=np.expand_dims(Xvr,0)
Xvr=np.expand_dims(Xvr,3)
Xvg=datav1['Xvg']
Xvg=Xvg.astype('float32')
# Xvg=np.expand_dims(Xvg,0)
Xvg=np.expand_dims(Xvg,3)
Xvb=datav1['Xvb']
Xvb=Xvb.astype('float32')
# Xvb=np.expand_dims(Xvb,0)
Xvb=np.expand_dims(Xvb,3)
pid=0
rawr=Xvr[pid]
rawr=np.expand_dims(rawr,0)
rawg=Xvg[pid]
rawg=np.expand_dims(rawg,0)
rawb=Xvb[pid]
rawb=np.expand_dims(rawb,0)

# %%
plt.imshow(np.concatenate((Xvr[0],Xvg[0],Xvb[0]),axis=2))
plt.title('measured image')
# Out:
# Text(0.5, 1.0, 'measured image')

# %%
reconMlist = [reconM1,reconM2,reconM3,reconM4,reconM5,reconM6,reconM7,reconM8,reconM9,reconM10,reconM11,reconM12,reconM13,reconM14]
recon_stack = np.zeros((15,ds1,ds2,3))
generated_stack = np.zeros((15,tsize,tsize,3))
# generated_stack3 = np.zeros((15,256,256,3))
ofs = loadmat("datasets//ofs.mat")
ofx = ofs['ofx']
ofy = ofs['ofy']
# ofx = np.ndarray.tolist(ofx)
# ofy = np.ndarray.tolist(ofy)
tcenter1 = 730
tcenter2 = 1010
lid=6
for rid in range(0,14):
    temp = reconout(reconMlist[rid],ofx[rid],ofy[rid],tcenter1,tcenter2,lid,rawr,rawg,rawb)
    recon_stack[rid] = temp
    inr = temp[:,:,0]
    inr = np.expand_dims(inr,0)
    inr = np.expand_dims(inr,3)
    ing = temp[:,:,1]
    ing = np.expand_dims(ing,0)
    ing = np.expand_dims(ing,3)
    inb = temp[:,:,2]
    inb = np.expand_dims(inb,0)
    inb = np.expand_dims(inb,3)
    generated_stack[rid] = generatorout(enhanceM,inr,ing,inb)

# %%
disd=[10,13,16,19,22,25,28,32,36,40,45,50,55,60]
plt.figure()
plt.subplot(1,2,1)
plt.imshow(recon_stack[5])
plt.title('25 cm reconM output')
plt.subplot(1,2,2)
plt.imshow(generated_stack[5])
plt.title('25 cm enhanceM output')

plt.figure()
plt.subplot(1,2,1)
plt.imshow(recon_stack[7])
plt.title('32 cm reconM output')
plt.subplot(1,2,2)
plt.imshow(generated_stack[7])
plt.title('32 cm enhanceM output')

plt.figure()
plt.subplot(1,2,1)
plt.imshow(recon_stack[10])
plt.title('45 cm reconM output')
plt.subplot(1,2,2)
plt.imshow(generated_stack[10])
plt.title('45 cm enhanceM output')
# Out:
# Text(0.5, 1.0, '45 cm enhanceM output')
